# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaBarsky/Math-152/blob/main/Classwork_3_7_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image

# %%
from google.colab import files

# %%
pixels = np.random.choice([True, False], (300,300))

# %%
img = Image.fromarray(pixels)
display(img)
img.save('dots.png')
# Out:
# <PIL.Image.Image image mode=1 size=300x300 at 0x7F3E6862EB80>

# %%
files.download('dots.png')

# %%
pixels.dtype
# Out:
# dtype('bool')

# %%
pixels.shape
# Out:
# (300, 300)

# %%
pixels[:10,:10]
# Out:
# array([[False,  True, False, False,  True, False, False,  True,  True,
#         False],
#        [False,  True, False, False,  True, False,  True,  True, False,
#         False],
#        [ True,  True,  True,  True, False,  True, False,  True, False,
#         False],
#        [ True,  True,  True,  True, False,  True,  True,  True, False,
#          True],
#        [False, False, False,  True, False,  True, False,  True,  True,
#         False],
#        [False,  True, False,  True,  True, False,  True, False, False,
#          True],
#        [ True,  True,  True, False,  True, False,  True,  True,  True,
#         False],
#        [False,  True,  True,  True,  True,  True,  True,  True, False,
#         False],
#        [False, False,  True,  True,  True, False, False,  True,  True,
#          True],
#        [ True, False,  True, False,  True,  True, False, False,  True,
#         False]])

# %%
x = np.arange(-50,50)
y = np.arange(-50,50)

# %%
xy = np.add.outer(x**2, y**2) #makes an addition table

# %%
even_arr = (xy >= 1000)

# %%
image = Image.fromarray(even_arr)
image.show()
# Out:
# <PIL.Image.Image image mode=1 size=100x100 at 0x7F763CB4E8E0>

# %%
print(xy)
# Out:
# [[5000 4901 4804 ... 4709 4804 4901]
#  [4901 4802 4705 ... 4610 4705 4802]
#  [4804 4705 4608 ... 4513 4608 4705]
#  ...
#  [4709 4610 4513 ... 4418 4513 4610]
#  [4804 4705 4608 ... 4513 4608 4705]
#  [4901 4802 4705 ... 4610 4705 4802]]

# %%
x_array = np.arange(-50,51)
y_array = np.arange(-50,51)

# %%
xy_array = np.add.outer(x_array**2, y_array**2)

# %%
print(xy_array)
# Out:
# [[5000 4901 4804 ... 4804 4901 5000]
#  [4901 4802 4705 ... 4705 4802 4901]
#  [4804 4705 4608 ... 4608 4705 4804]
#  ...
#  [4804 4705 4608 ... 4608 4705 4804]
#  [4901 4802 4705 ... 4705 4802 4901]
#  [5000 4901 4804 ... 4804 4901 5000]]

# %%
type(xy_array)
# Out:
# numpy.ndarray

# %%
np.size(xy_array)
# Out:
# 10201

# %%
circ_array = (xy_array <= 2500)

# %%
circ_array.shape
# Out:
# (101, 101)

# %%
np.sum(circ_array)
# Out:
# 7845

# %%
image = Image.fromarray(circ_array)
image.show()
# Out:
# <PIL.Image.Image image mode=1 size=101x101 at 0x7F763CB51C70>

# %%
pixels = np.random.randint(0,256,(300,300,3), dtype = np.uint8)

# %%
pixels.dtype
# Out:
# dtype('uint8')

# %%
pixels = pixels.astype(np.uint8) #converts to unsigned 8 bit int

# %%
pixels.dtype
# Out:
# dtype('uint8')

# %%
image = Image.fromarray(pixels)
image.show()
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7F763CCE34C0>

# %%
pixels = np.random.randint(0,256,(300,300,3), dtype = np.uint8)

# %%
x_array = np.arange(-50,51)
y_array = np.arange(-50,51)

# %% [markdown]
# ###**Circle**

# %% [markdown]
# **Anti-aliasing equation:**
#
# $f(x) = \frac{1}{|x^2+y^2-1|}$
#
# This returns very large numbers where the $f(x)$ is closest to zero.

# %%
x_arr = np.linspace(-1,1,500)
y_arr = x_arr
xy_arr = np.add.outer(x_arr**2, y_arr**2)

circ_arr = (1/np.abs(xy_arr - 1))
circ_arr_weighted = circ_arr.astype(np.uint8)

print(max(circ_arr[1]))
# Out:
# 7545.484848482877

# %%
test_values = np.array([1,100,1000,10000])
tested_weights = test_values.astype(np.uint8)

print(tested_weights)
# Out:
# [  1 100 232  16]

# %%
im = Image.fromarray(circ_arr)
im.show()
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF549C0C250>

# %% [markdown]
# ###**Hyperbola**

# %%
x_arr_hyp = np.linspace(-1,1,500)
y_arr_hyp = x_arr_hyp
xy_arr_hyp = np.subtract.outer((x_arr**2)/.2, (y_arr**2)/1)

hyp_arr = (1/np.abs(xy_arr_hyp - 1))
hyp_arr_weighted = hyp_arr.astype(np.uint8)

im = Image.fromarray(hyp_arr)
im.show()
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF54A79FE50>

# %% [markdown]
# ###**Parabola**

# %%
x_arr_parab = np.linspace(-1,1,500)
y_arr_parab = x_arr_parab
xy_arr_parab = np.add.outer(y_arr_parab,x_arr_parab**2)
print(xy_arr_parab)

parab_arr = (1/np.abs(xy_arr_parab - 1))
parab_arr_weighted = parab_arr.astype(np.uint8)

im = Image.fromarray(parab_arr)
im.show()
# Out:
# [[ 0.00000000e+00 -7.99996787e-03 -1.59678074e-02 ... -1.59678074e-02
#   -7.99996787e-03  0.00000000e+00]
#  [ 4.00801603e-03 -3.99195184e-03 -1.19597913e-02 ... -1.19597913e-02
#   -3.99195184e-03  4.00801603e-03]
#  [ 8.01603206e-03  1.60641925e-05 -7.95177529e-03 ... -7.95177529e-03
#    1.60641925e-05  8.01603206e-03]
#  ...
#  [ 1.99198397e+00  1.98398400e+00  1.97601616e+00 ...  1.97601616e+00
#    1.98398400e+00  1.99198397e+00]
#  [ 1.99599198e+00  1.98799202e+00  1.98002418e+00 ...  1.98002418e+00
#    1.98799202e+00  1.99599198e+00]
#  [ 2.00000000e+00  1.99200003e+00  1.98403219e+00 ...  1.98403219e+00
#    1.99200003e+00  2.00000000e+00]]
# <PIL.Image.Image image mode=L size=500x500 at 0x7F3E4BA270A0>
