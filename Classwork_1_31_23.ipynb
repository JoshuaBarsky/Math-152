# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaBarsky/Math-152/blob/main/Classwork_1_31_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Modeling a simple harmonic oscillator -- differential equations
def boing(y_start, v_start, dt):
  y = y_start
  v = v_start
  for t in range(100):
    y_new = y+v*dt
    v_new = v+y_new*dt
    y, v = v_new, y_new
    E = y**2 + v**2 #added line
    print(y,v,E)
    #also worth noting 2nd order-4th order -- Runge-Kutta method


#Euclidean algorithm -- Euclid 300 BCE - lived in Alexandria (Egypt) - Elements (circulated continuously since Euclid Book VII Prop 1-2)
#(also found on Suan Shu Shu)
def Shu_algorithm(a, b):
  while (a != b):
    if a<b:
      b = b-a
    elif b<a:
      a = a-b
  return a, b


#While loop Safety!!
def factorial(n):
  p=j=1
  t=0   #limited steps safety
  while (j <= n) & (t < 1000):
    p = p*j
    j=j+1 #increment safety - less than n
    t=t+1 #incrementing safety - less than maximum instructions
  return p


#Project 1 Group --> sign up on canvas
#NB 1 graded now/soon
#midterm next Thursday -- closed computer closed book - only paper and pen

# %%
print(Shu_algorithm(49, 42))
# %timeit Shu_algorithm(49, 42)
# Out:
# (7, 7)
# 770 ns ± 13 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
boing(2, 0, 0.01)
# Out:
# 0.02 2.0 4.0004
# 2.0004 0.04 4.00320016
# 0.060008 2.0008 4.006801600064
# 2.0016001599999997 0.080016 4.012805760768025
# 0.1000400032 2.0024003199999996 4.019615043776357
# 2.0036009600639995 0.1200640064 4.0288321728022
# 0.14011202240128 2.0048016001279994 4.038860834697163
# 2.006403200512025 0.16016003840256002 4.051305040926006
# 0.18024008641152053 2.0080048008960505 4.06456976917122
# 2.010008002240255 0.20032013442048105 4.080260325324101
# 0.22044024645632565 2.0120112035844597 4.096782985607112
# 2.0144168071693813 0.24056035849217025 4.115744359084366
# 0.26072858259971327 2.016822410754303 4.135552030305254
# 2.0196313788213756 0.2808968067072563 4.157813922338264
# 0.3011212101761408 2.022440346888448 4.18093893994021
# 2.0256538030248983 0.3213456136450253 4.206536333118131
# 0.3416342862366388 2.0288672591613484 4.233016340829299
# 2.032486488749631 0.36192295882825226 4.2619895550768
# 0.3822840160116314 2.0361057183379137 4.291867565146333
# ...
