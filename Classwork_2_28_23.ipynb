# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshuaBarsky/Math-152/blob/main/Classwork_2_28_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Lets make pretty pictures.**

# %% [markdown]
# ---
#
#
#
# remember to keep code blocks in seperate code cells.
#
# ---

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
xlist = np.random.uniform(-10,10,1000)

# %%
ylist = np.random.uniform(-10,10,1000)

# %% [markdown]
# ---
#
#
#
# alpha ≡ opacity/transparecy
#
# c = color
#
# s = size
#
#
#
# ---

# %%
plt.figure(figsize=(6,6))
plt.scatter(xlist,ylist,alpha=0.5,c='GOLD',s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Go Slugs')
plt.show()

# %%
clist = (xlist**2+ylist**2)

# %% [markdown]
# ---
#
#
# 'clist' is the same as the list of squared radii (i.e. rlist**2).
#
#
#
# ---

# %%
plt.figure(figsize=(6,6))
plt.scatter(xlist,ylist,alpha=0.5,c=clist,s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Go Slugs')
plt.show()

# %% [markdown]
# ---
#
# You can add the following to change the palette:
#
# cmap = 'Blues'
#
# cmap = 'viridis'
#
# cmap = 'inferno'
#
# cmap = 'coolwarm'
#
# cmap = 'Set1'
#
# cmap = 'pastel1'
#
# cmap = 'Dark2'
#
# cmap = 'Paired'
#
# **More info at the following website:**
#
# https://matplotlib.org/stable/tutorials/colors/colormaps.html
#
#
#
# ---

# %%
plt.figure(figsize=(6,6))
plt.scatter(xlist,ylist,alpha=0.5,c=clist,cmap='Set1',s=50)
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.title('Go Slugs')
plt.show()

# %% [markdown]
# ##**Different kinds of data**

# %% [markdown]
# ---
#
#
#
# **Numerical:**
#
# rocket thrust 0...high → palette can be black to bright orange
#
# speed 0...high
#
# temperature cold...warm → palette can be cold to warm
#
#
# **Categorical:**
#
# A finite number of 'categories' → discrete colors
#
#
#
# ---
#
# Data → stuff you see
#
#
# **Representing data:**
#
# Position → (x, y) , (r, Θ)
#
# Color → RGB, Hue, Brightness, Transparency
#
# Shape & dot-size
#
# ⋆*3D graphs are generally something to avoid. Keep things 2D.*
#
# ---

# %%
n_array = np.arange(1,1000000)
s_array = np.sqrt(n_array)
e_array = s_array-np.floor(s_array)

# %% [markdown]
# ##**This is one dimensional distribution:**

# %%
u_list = np.random.uniform(-10,10,10000)

# %%
print(u_list[:10])
# Out:
# [-8.54553095  1.14598539 -2.11846245  1.24991979 -2.04711359  5.83433959
#   8.42408258 -0.38699962  8.37703073  9.40709279]

# %%
plt.hist(u_list, bins=20) #this is what to expect in a uniform distribution
# Out:
# (array([517., 492., 482., 508., 482., 563., 486., 530., 533., 488., 519.,
#         489., 479., 498., 504., 484., 471., 498., 503., 474.]),
#  array([-9.99647374e+00, -8.99669922e+00, -7.99692469e+00, -6.99715017e+00,
#         -5.99737564e+00, -4.99760111e+00, -3.99782659e+00, -2.99805206e+00,
#         -1.99827754e+00, -9.98503009e-01,  1.27151679e-03,  1.00104604e+00,
#          2.00082057e+00,  3.00059509e+00,  4.00036962e+00,  5.00014415e+00,
#          5.99991867e+00,  6.99969320e+00,  7.99946773e+00,  8.99924225e+00,
#          9.99901678e+00]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# **Be very careful with discrete data:**

# %%
d_list = np.random.randint(-10,10,10000)

# %%
plt.hist(d_list, bins = 7)
# Out:
# (array([1438., 1494., 1532., 1018., 1528., 1480., 1510.]),
#  array([-10.        ,  -7.28571429,  -4.57142857,  -1.85714286,
#           0.85714286,   3.57142857,   6.28571429,   9.        ]),
#  <BarContainer object of 7 artists>)

# %%
np.max(d_list)
# Out:
# 9

# %%
n_list = np.random.normal(loc=1, scale = 3, size = 10000) #loc = mean, scale = std

# %%
plt.hist(n_list, bins = 20)
# Out:
# (array([   6.,   11.,   39.,   98.,  189.,  398.,  695., 1048., 1380.,
#         1506., 1422., 1261.,  895.,  566.,  266.,  141.,   52.,   16.,
#            8.,    3.]),
#  array([-10.12472342,  -8.98541112,  -7.84609882,  -6.70678652,
#          -5.56747423,  -4.42816193,  -3.28884963,  -2.14953733,
#          -1.01022504,   0.12908726,   1.26839956,   2.40771186,
#           3.54702416,   4.68633645,   5.82564875,   6.96496105,
#           8.10427335,   9.24358564,  10.38289794,  11.52221024,
#          12.66152254]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# Distribution equation:
#
# $f(x)$ = $\frac{1}{\sqrt(2\pi)}e^{-\frac{x^2}{2}}$

# %%
u_list = np.random.uniform(-10,10,10000)
d_list = np.random.randint(-10,10,1000)
n_list = np.random.normal(loc=1, scale=3, size=10000)
p_list = ___.poisson(lam=3, size=10000)
plt.hist(any_list, bins=_)
